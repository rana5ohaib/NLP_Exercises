# %%
import re

string = "000-000-0000
000 000 0000
000.000.0000
(000)000-0000
(000)000 0000
(000)000.0000
(000) 000-0000
(000) 000 0000
(000) 000.0000
000-0000
000 0000
000.0000
0000000
0000000000
(000)0000000"

regex = re.compile(r'(([(]{0,1})([0]{3})([)]{0,1})([-| |.]{0,1})([0]{3,4})([-| |.]{0,1})([0]{0,4}))')
r = regex.split(string)
# Out:
# ['', '', '000', '', '-', '000', '-', '0000', ' ', '', '000', '', ' ', '000', ' ', '0000', ' ', '', '000', '', '.', '000', '.', '0000', ' ', '(', '000', ')', '', '000', '-', '0000', ' ', '(', '000', ')', '', '000', ' ', '0000', ' ', '(', '000', ')', '', '000', '.', '0000', ' ', '(', '000', ')', ' ', '000', '-', '0000', ' ', '(', '000', ')', ' ', '000', ' ', '0000', ' ', '(', '000', ')', ' ', '000', '.', '0000', ' ', '', '000', '', '-', '0000', ' ', '000', ' 0', '', '000', '', ' ', '000', '.', '0000', ' ', '', '000', '', '', '0000', ' ', '0000', '', '', '000', '', '', '000', ' ', '', '', '(', '000', ')', '', '0000', '', '000', '']
